# %% [markdown]
# # Monitoring AI Models For Bias and Fairness with segmentation

# %%
# !ls
# Out:
# sample_data

# %%
# Installing whylogs (WhyLabs.ai is an AI observability platform that prevents data & model performance degradation by allowing you to monitor your data and machine learning models in production)
# !pip install whylogs[viz]==1.3.0
# Out:
# Requirement already satisfied: whylogs[viz]==1.3.0 in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (3.20.3)
# Requirement already satisfied: requests<3.0,>=2.27 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.30.0.0 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (2.32.0.20240712)
# Requirement already satisfied: typing-extensions>=3.10 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (4.12.2)
# Requirement already satisfied: whylabs-client<0.6.0,>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (0.5.10)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (3.4.1.dev3)
# Requirement already satisfied: Pillow<10.0.0,>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (9.4.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (1.25.2)
# Requirement already satisfied: pybars3<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (0.9.7)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from whylogs[viz]==1.3.0) (1.11.4)
# Requirement already satisfied: PyMeta3>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from pybars3<0.10,>=0.9->whylogs[viz]==1.3.0) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.27->whylogs[viz]==1.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.27->whylogs[viz]==1.3.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.27->whylogs[viz]==1.3.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.27->whylogs[viz]==1.3.0) (2024.7.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from whylabs-client<0.6.0,>=0.5.3->whylogs[viz]==1.3.0) (2.8.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->whylogs[viz]==1.3.0) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->whylogs[viz]==1.3.0) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->whylogs[viz]==1.3.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->whylogs[viz]==1.3.0) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->whylabs-client<0.6.0,>=0.5.3->whylogs[viz]==1.3.0) (1.16.0)

# %% [markdown]
# #⚖️ ML Monitoring for Bias: Monitoring for Bias & Fairness with Tracing

# %%
# Imports
import whylogs as why
import numpy as np
import pandas as pd
import datetime
import os

from sklearn.model_selection import train_test_split


from sklearn.datasets import load_iris

# Set to show all columns in dataframe
pd.set_option("display.max_columns", None)

# %%
# Load iris data as dataframe(df)
data_iris = load_iris(as_frame=True)

# List names in dataset
print(list(data_iris.target_names))
print(list(data_iris.data))
# Out:
# ['setosa', 'versicolor', 'virginica']
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# ## Train a Machine Learning Model (quickly)

# %%
# Train baseline Model
# KNN Model
from sklearn import neighbors
knn = neighbors.KNeighborsClassifier(n_neighbors=5)

# Create featurex and target data varaible
X, y = data_iris.data, data_iris.target

#create train & test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=42,
                                                    stratify=y)
# Train model
knn.fit(X_train, y_train)

# Predict the labels on test data sset
y_pred = knn.predict(X_test)

# Print model accuracy
knn.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# ### KNN intuition
#
# Just a little bit of intuition how kNN models work.
#
# This will be helpful for troubleshooting some issues later!
#
# Iris data plotted by:
#
# `x = 'sepal length (cm)', y = 'petal width (cm)'`
#
# ![](https://github.com/sagecodes/intro-machine-learning/raw/master/irisknn.png)

# %% [markdown]
# ## Import data batches

# %%
 # Import data batches
url = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_15_statefl_1.csv'
data_batch_1 = pd.read_csv(url)

url2 = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_16_statefl_1.csv'
data_batch_2 = pd.read_csv(url2)

url3 = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_17_statefl_1.csv'
data_batch_3 = pd.read_csv(url3)

url4 = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_18_statefl_1.csv'
data_batch_4 = pd.read_csv(url4)

url5 = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_19_statefl_1.csv'
data_batch_5 = pd.read_csv(url5)

url6 = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_20_statefl_1.csv'
data_batch_6 = pd.read_csv(url6)

url7 = 'https://raw.githubusercontent.com/sagecodes/sythetic_iris_data/main/iris_21_statefl_1.csv'
data_batch_7 = pd.read_csv(url7)

# iris feature names
feature_names = ['sepal length (cm)', 'sepal width (cm)','petal length (cm)','petal width (cm)', 'state']

# separate targets
X_batch_1 = data_batch_1[feature_names]
X_batch_2 = data_batch_2[feature_names]
X_batch_3 = data_batch_3[feature_names]
X_batch_4 = data_batch_4[feature_names]
X_batch_5 = data_batch_5[feature_names]
X_batch_6 = data_batch_6[feature_names]
X_batch_7 = data_batch_7[feature_names]

# We'll save the target values for later!
y_batch_1 = data_batch_1['target']
y_batch_2 = data_batch_2['target']
y_batch_3 = data_batch_3['target']
y_batch_4 = data_batch_4['target']
y_batch_5 = data_batch_5['target']
y_batch_6 = data_batch_6['target']
y_batch_7 = data_batch_7['target']


# create list of our batches
dfs = [X_batch_1, X_batch_4, X_batch_5, X_batch_6, X_batch_2, X_batch_3, X_batch_7]

df_target = [y_batch_1, y_batch_4, y_batch_5, y_batch_6, y_batch_2, y_batch_3, y_batch_7]

# %%
dfs[0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                4.9               4.0                1.6               0.3
# 1                4.9               3.5                1.3               0.1
# 2                5.9               3.0                5.1               1.3
# 3                5.2               3.3                1.6               0.3
# 4                4.6               3.2                1.2               0.3
#
#         state
# 0  Washington
# 1  Washington
# 2  Washington
# 3  Washington
# 4  Washington

# %% [markdown]
# ## Creating profiles with whylogs
#
#
# Profiles generated with whylogs are:
#
# - Secure
# - Efficient
# - Customizable
# - Mergeable

# %%
# create profile
profile1 = why.log(X_batch_1)

profile_view1 = profile1.view()
profile_view1.to_pandas()
# Out:
#                    cardinality/est  cardinality/lower_1  cardinality/upper_1  \
# column
# cls_output                3.000000                  3.0             3.000150
# ground_truth              3.000000                  3.0             3.000150
# petal length (cm)        49.000006                 49.0            49.002452
# petal width (cm)         24.000001                 24.0            24.001200
# prob_output               3.000000                  3.0             3.000150
# sepal length (cm)        33.000003                 33.0            33.001650
# sepal width (cm)         19.000001                 19.0            19.000950
# state                     3.000000                  3.0             3.000150
#
#                    counts/inf  counts/n  counts/nan  counts/null  \
# column
# cls_output                  0       150           0            0
# ground_truth                0       150           0            0
# petal length (cm)           0       150           0            0
# petal width (cm)            0       150           0            0
# prob_output                 0       150           0            0
# sepal length (cm)           0       150           0            0
# sepal width (cm)            0       150           0            0
# state                       0       150           0            0
#
#                    distribution/max  distribution/mean  distribution/median  \
# column
# cls_output                      NaN           0.000000                  NaN
# ground_truth                    NaN           0.000000                  NaN
# petal length (cm)               7.5           4.041333                  4.3
# petal width (cm)                2.7           1.207333                  1.3
# prob_output                     1.0           0.973333                  1.0
# sepal length (cm)               7.7           5.856000                  5.8
# sepal width (cm)                4.0           2.996000                  2.9
# state                           NaN           0.000000                  NaN
#
#                    distribution/min  distribution/n  distribution/q_01  \
# column
# cls_output                      NaN               0                NaN
# ground_truth                    NaN               0                NaN
# petal length (cm)               1.1             150                1.1
# petal width (cm)                0.0             150                0.1
# prob_output                     0.6             150                0.6
# sepal length (cm)               4.2             150                4.2
# sepal width (cm)                2.2             150                2.2
# state                           NaN               0                NaN
#
#                    distribution/q_05  distribution/q_10  distribution/q_25  \
# column
# cls_output                       NaN                NaN                NaN
# ground_truth                     NaN                NaN                NaN
# petal length (cm)                1.3                1.5                2.4
# petal width (cm)                 0.1                0.2                0.3
# prob_output                      0.8                1.0                1.0
# sepal length (cm)                4.7                4.9                5.1
# sepal width (cm)                 2.3                2.4                2.7
# state                            NaN                NaN                NaN
#
#                    distribution/q_75  distribution/q_90  distribution/q_95  \
# column
# cls_output                       NaN                NaN                NaN
# ground_truth                     NaN                NaN                NaN
# petal length (cm)                5.4                6.2                6.8
# petal width (cm)                 1.9                2.2                2.4
# prob_output                      1.0                1.0                1.0
# sepal length (cm)                6.5                7.1                7.2
# sepal width (cm)                 3.3                3.6                3.8
# state                            NaN                NaN                NaN
#
#                    distribution/q_99  distribution/stddev  \
# column
# cls_output                       NaN             0.000000
# ground_truth                     NaN             0.000000
# petal length (cm)                7.5             1.776664
# petal width (cm)                 2.5             0.769651
# prob_output                      1.0             0.088740
# sepal length (cm)                7.7             0.847775
# sepal width (cm)                 4.0             0.448395
# state                            NaN             0.000000
#
#                                      frequent_items/frequent_strings  \
# column
# cls_output         [FrequentItem(value='virginica', est=51, upper...
# ground_truth       [FrequentItem(value='virginica', est=50, upper...
# petal length (cm)                                                NaN
# petal width (cm)                                                 NaN
# prob_output                                                      NaN
# sepal length (cm)                                                NaN
# sepal width (cm)                                                 NaN
# state              [FrequentItem(value='Washington', est=50, uppe...
#
#                                  type  types/boolean  types/fractional  \
# column
# cls_output         SummaryType.COLUMN              0                 0
# ground_truth       SummaryType.COLUMN              0                 0
# petal length (cm)  SummaryType.COLUMN              0               150
# petal width (cm)   SummaryType.COLUMN              0               150
# prob_output        SummaryType.COLUMN              0               150
# sepal length (cm)  SummaryType.COLUMN              0               150
# sepal width (cm)   SummaryType.COLUMN              0               150
# state              SummaryType.COLUMN              0                 0
#
#                    types/integral  types/object  types/string  types/tensor
# column
# cls_output                      0             0           150             0
# ground_truth                    0             0           150             0
# petal length (cm)               0             0             0             0
# petal width (cm)                0             0             0             0
# prob_output                     0             0             0             0
# sepal length (cm)               0             0             0             0
# sepal width (cm)                0             0             0             0
# state                           0             0           150             0

# %% [markdown]
# ## Writing data profiles to to WhyLabs
#
# ![](https://camo.githubusercontent.)

# %%
# set authentication & project keys
os.environ["WHYLABS_DEFAULT_ORG_ID"] = 'org-ZSqhdy'
os.environ["WHYLABS_API_KEY"] = 'IxGGWOPQDD.g90N0Dg1p3Wona7rwxqPrZzTRH6uNeWjtfDWlcxyVM5ee3AfT2Lgd:org-ZSqhdy'
os.environ["WHYLABS_DEFAULT_DATASET_ID"] = 'model-2'

# %% [markdown]
# ### write a single profile
# ```
# profile = why.log(df)
# profile.writer("whylabs").write()
# ```

# %% [markdown]
# ### Create dataframe with model predictions

# %%
# Get predictions with model & append to df
pred_dfs = dfs

class_names = ['setosa', 'versicolor', 'virginica']

for i, df in enumerate(pred_dfs):
    y_pred = knn.predict(df.iloc[:, :4])
    y_prob = knn.predict_proba(df.iloc[:, :4])
    pred_scores = []
    pred_classes = []

    for pred in y_pred:
      pred_classes.append(class_names[pred])
    df['cls_output'] = pred_classes
    for prob in y_prob:
      pred_scores.append(max(prob))
    df['prob_output'] = pred_scores

# %%
pred_dfs[-1]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.5               2.9                4.4               1.2
# 1                  4.7               3.1                1.3               0.3
# 2                  4.7               3.0                1.4               0.2
# 3                  5.2               3.7                1.4               0.3
# 4                  6.8               3.2                6.2               1.6
# ..                 ...               ...                ...               ...
# 145                5.9               3.0                5.8               2.6
# 146                4.8               2.3                3.7               1.4
# 147                5.3               2.7                4.3               1.3
# 148                5.8               3.2                5.7               1.9
# 149                5.1               3.9                1.5               0.1
#
#           state  cls_output  prob_output ground_truth
# 0    Washington  versicolor          1.0   versicolor
# 1    Washington      setosa          1.0       setosa
# 2    Washington      setosa          1.0       setosa
# 3    Washington      setosa          1.0       setosa
# 4    Washington   virginica          1.0    virginica
# ..          ...         ...          ...          ...
# 145    Missouri   virginica          1.0    virginica
# 146    Missouri  versicolor          1.0   versicolor
# 147    Missouri  versicolor          1.0   versicolor
# 148    Missouri   virginica          1.0    virginica
# 149    Missouri      setosa          1.0       setosa
#
# [150 rows x 8 columns]

# %% [markdown]
# ### Backfilling data in WhyLabs

# %%
from whylogs.core.schema import DatasetSchema
from whylogs.core.segmentation_partition import segment_on_column

# %%
# back fill 1 day per batch
for i, df in enumerate(pred_dfs):
    # walking backwards. Each dataset has to map to a date to show up as a different batch in WhyLabs
    dt = datetime.datetime.now(tz=datetime.timezone.utc) - datetime.timedelta(days=i)

    # create profile for each batch of data
    profile = why.log(df, schema=DatasetSchema(segments=segment_on_column("state")))

    # set the dataset timestamp for the profile
    profile.set_dataset_timestamp(dt)
    # write the profile to the WhyLabs platform
    profile.writer("whylabs").write()

# %% [markdown]
# ###Classification Performance Metrics

# %%
# Append ground truth data to dataframe
for i, df in enumerate(pred_dfs):
    df['ground_truth'] = df_target[i]

# %%
pred_dfs[0]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  4.9               4.0                1.6               0.3
# 1                  4.9               3.5                1.3               0.1
# 2                  5.9               3.0                5.1               1.3
# 3                  5.2               3.3                1.6               0.3
# 4                  4.6               3.2                1.2               0.3
# ..                 ...               ...                ...               ...
# 145                6.0               2.9                6.6               2.0
# 146                5.3               3.0                1.6               0.1
# 147                5.6               2.3                4.2               1.2
# 148                5.3               3.1                1.4               0.3
# 149                6.4               2.7                5.4               1.9
#
#           state  cls_output  prob_output ground_truth
# 0    Washington      setosa          1.0       setosa
# 1    Washington      setosa          1.0       setosa
# 2    Washington  versicolor          0.8   versicolor
# 3    Washington      setosa          1.0       setosa
# 4    Washington      setosa          1.0       setosa
# ..          ...         ...          ...          ...
# 145    Missouri   virginica          1.0    virginica
# 146    Missouri      setosa          1.0       setosa
# 147    Missouri  versicolor          1.0   versicolor
# 148    Missouri      setosa          1.0       setosa
# 149    Missouri   virginica          1.0    virginica
#
# [150 rows x 8 columns]

# %%
from whylogs import log_classification_metrics
# from whylogs.core.schema import DatasetSchema
# from whylogs.core.segmentation_partition import segment_on_column

# %%
for i, df in enumerate(pred_dfs):

  segmented_classification_results = log_classification_metrics(
    df,
    target_column = "ground_truth",
    prediction_column = "cls_output",
    schema = DatasetSchema(segments=segment_on_column("state"))
  )
   # walking backwards. Each dataset has to map to a date to show up as a different batch in WhyLabs
  dt = datetime.datetime.now(tz=datetime.timezone.utc) - datetime.timedelta(days=i)

  # profile = segmented_classification_results.profile()
  segmented_classification_results.set_dataset_timestamp(dt)

  segmented_classification_results.writer("whylabs").write()
